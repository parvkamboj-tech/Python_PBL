# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd

df = pd.read_csv("wifi_final_dataset.csv")
df.head()
# Out:
#    bandwidth  latency  packet_loss  devices         load  congestion
# 0        496    0.011            2        2   495.994544           0
# 1       1762    0.008            2        2  1761.985904           1
# 2       1068    0.005            2        2  1067.994660           1
# 3        900    0.006            2        2   899.994600           1
# 4       2126    0.010            2        2  2125.978740           1

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 82332 entries, 0 to 82331
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   bandwidth    82332 non-null  int64
#  1   latency      82332 non-null  float64
#  2   packet_loss  82332 non-null  int64
#  3   devices      82332 non-null  int64
#  4   load         82332 non-null  float64
#  5   congestion   82332 non-null  int64
# dtypes: float64(2), int64(4)
# memory usage: 3.8 MB

# %%
df.describe()
# Out:
#           bandwidth       latency   packet_loss       devices           load  \
# count  8.233200e+04  82332.000000  82332.000000  82332.000000   82332.000000
# mean   2.122769e+04   1006.756146     11.873804     36.212408    1908.589444
# std    2.300577e+05   4710.444411    140.398887    206.713176    8030.666527
# min    2.400000e+01      0.000000      0.000000      1.000000       1.111764
# 25%    1.140000e+02      0.008000      2.000000      2.000000     113.999658
# 50%    8.800000e+02     14.138000      2.000000      8.000000     300.770005
# 75%    2.814000e+03    719.360250      4.000000     22.000000     806.019920
# max    1.472823e+07  59999.989000   9376.000000  12660.000000  256234.484877
#
#          congestion
# count  82332.000000
# mean       0.439829
# std        0.496369
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000

# %%
df.hist(figsize=(10,8))
plt.show()

# %%
sns.countplot(x="congestion", data=df)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.show()

# %%
sns.boxplot(x="congestion", y="latency", data=df)
plt.show()

# %%
sns.boxplot(x="congestion", y="bandwidth", data=df)
plt.show()

# %%
import seaborn as sns
sns.scatterplot(x="devices", y="latency", hue="congestion", data=df)
plt.show()

# %% [markdown]
# Key Insights:
# - Higher latency increases congestion
# - High bandwidth usage leads to congestion
# - More devices increase network load
